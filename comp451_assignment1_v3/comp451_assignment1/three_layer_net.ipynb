# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from comp451.classifiers.neural_net import ThreeLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `ThreeLayerNet` in the file `comp451/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return ThreeLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `comp451/classifiers/neural_net.py` and look at the method `ThreeLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.03596154, -0.01613583, -0.00048556],
  [-0.09480192, 0.20724618, -0.09763798],
  [-0.07015667, 0.17081869, -0.07675745],
  [ 0.01473052, 0.09321097, -0.0395178 ],
  [-0.05306489, 0.04729807,  0.01750587]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.03596154 -0.01613583 -0.00048556]
#  [-0.09480192  0.20724618 -0.09763798]
#  [-0.07015667  0.17081869 -0.07675745]
#  [ 0.01473052  0.09321097 -0.0395178 ]
#  [-0.05306489  0.04729807  0.01750587]]
#
# correct scores:
# [[-0.03596154 -0.01613583 -0.00048556]
#  [-0.09480192  0.20724618 -0.09763798]
#  [-0.07015667  0.17081869 -0.07675745]
#  [ 0.01473052  0.09321097 -0.0395178 ]
#  [-0.05306489  0.04729807  0.01750587]]
#
# Difference between your scores and correct scores:
# 4.807962381448306e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.1760667703015604
print(loss.shape)
# print("check",loss, loss[0] + loss[1])
# should be very small, we get < 1e-12

# if np.abs(loss-correct_loss) < 1e-12:
#     print("Good")

print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# ()
# Difference between your loss and correct loss:
# 0.0

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, `b2`, `W3` and `b3`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from comp451.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, W3, b1, b2 and b3.
regp = 0.5
loss, grads = net.loss(X, y, reg=regp)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=regp)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W3 max relative error: 1.000000e+00
# b3 max relative error: 8.494216e-11
# W2 max relative error: 1.000000e+00
# b2 max relative error: 4.590210e-10
# W1 max relative error: 1.000000e+00
# b1 max relative error: 7.670388e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `ThreeLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `ThreeLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a three-layer network on toy data. You should achieve a training loss less than 0.21.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.20626597643080502

# %% [markdown]
# # Load the data
# Now that you have implemented a three-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from comp451.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the three-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'comp451/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
np.random.seed(1)
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = ThreeLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-2, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# h=50,b=200, lr=0.01, reg =0.25
# iteration 0 / 1000: loss 2.341590
# iteration 100 / 1000: loss 2.326638
# iteration 200 / 1000: loss 2.307268
# iteration 300 / 1000: loss 2.135436
# iteration 400 / 1000: loss 2.089884
# iteration 500 / 1000: loss 1.934895
# iteration 600 / 1000: loss 1.927651
# iteration 700 / 1000: loss 1.937027
# iteration 800 / 1000: loss 1.866515
# iteration 900 / 1000: loss 1.910977
# Training Accuracy 0.40620408163265304, Validation Accuracy 0.415
# Validation accuracy:  0.415

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.307 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
#Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from comp451.vis_utils import visualize_grid

#Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 50% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (50% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$ Similarly, to SVM and Softmax tuning of hyperparameters, I have used grid search technique. I stored the all the possible combniations of different learning rates, regularization parameters, hidden units, and batch sizes into an array. After that I trained the model on each combniation and selected the model which has highest validation accuracy.

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# learning_rates = [3 * (1e-2) , 3 * (1e-2)/2]
learning_rates = [0.015, 0.018]
regularization_strengths = [0.0001, 0.001, 0.002]
hidden_sizes = [400]
batch_sizes = [350,400]


results = {}
best_val = -1
grid_search = [ (lr,rg,h,b) for lr in learning_rates for rg in regularization_strengths for h in hidden_sizes for b in batch_sizes]
best_lr = -1
best_reg = -1
best_batch = -1
best_hidden = -1

for lr, rg, h_s, b in grid_search:
    # Create a new sofmax instance
    net = ThreeLayerNet(input_size, h_s, num_classes)

    # Train the network
    stats = net.train(X_train, y_train, X_val, y_val, num_iters=1000, batch_size=b,learning_rate=lr,learning_rate_decay=0.95, reg=rg, verbose=True)
    # Predict values for training set
    y_train_pred = net.predict(X_train)
    # Calculate accuracy
    train_accuracy = np.mean(y_train_pred == y_train)
    # Predict values for validation set
    y_val_pred = net.predict(X_val)
    # Calculate accuracy
    val_accuracy = np.mean(y_val_pred == y_val)
    # Save results
    results[(lr,rg, h_s, b)] = (train_accuracy, val_accuracy)
    print("Training Accuracy {t}, Validation Accuracy {v}".format(t=train_accuracy, v=val_accuracy))
    if best_val <= val_accuracy:
        best_net = net
        best_val = val_accuracy
        best_lr = lr
        best_reg = rg
        best_batch = b
        best_hidden = h_s


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# h=350,b=350, lr=0.01, reg =0.0001
# iteration 0 / 1000: loss 2.302660
# iteration 100 / 1000: loss 2.102117
# iteration 200 / 1000: loss 1.806202
# iteration 300 / 1000: loss 1.671213
# iteration 400 / 1000: loss 1.625476
# iteration 500 / 1000: loss 1.636697
# iteration 600 / 1000: loss 1.614576
# iteration 700 / 1000: loss 1.401149
# iteration 800 / 1000: loss 1.467007
# iteration 900 / 1000: loss 1.291552
# Training Accuracy 0.523469387755102, Validation Accuracy 0.506
# Training Accuracy 0.523469387755102, Validation Accuracy 0.506
# h=350,b=400, lr=0.01, reg =0.0001
# iteration 0 / 1000: loss 2.302781
# iteration 100 / 1000: loss 2.138820
# iteration 200 / 1000: loss 1.801872
# iteration 300 / 1000: loss 1.618870
# iteration 400 / 1000: loss 1.672419
# iteration 500 / 1000: loss 1.510231
# iteration 600 / 1000: loss 1.443214
# iteration 700 / 1000: loss 1.465599
# iteration 800 / 1000: loss 1.349176
# iteration 900 / 1000: loss 1.343898
# Training Accuracy 0.5320204081632653, Validation Accuracy 0.478
# Training Accuracy 0.5320204081632653, Validation Accuracy 0.478
# h=400,b=350, lr=0.01, reg =0.0001
# iteration 0 / 1000: loss 2.302691
# iteration 100 / 1000: loss 2.013248
# iteration 200 / 1000: loss 1.804707
# iteration 300 / 1000: loss 1.697232
# iteration 400 / 1000: loss 1.624678
# iteration 500 / 1000: loss 1.553663
# iteration 600 / 1000: loss 1.456261
# iteration 700 / 1000: loss 1.441003
# iteration 800 / 1000: loss 1.281726
# iteration 900 / 1000: loss 1.336969
# Training Accuracy 0.5467142857142857, Validation Accuracy 0.495
# Training Accuracy 0.5467142857142857, Validation Accuracy 0.495
# h=400,b=400, lr=0.01, reg =0.0001
# iteration 0 / 1000: loss 2.302710
# iteration 100 / 1000: loss 2.068558
# iteration 200 / 1000: loss 1.694436
# iteration 300 / 1000: loss 1.622932
# iteration 400 / 1000: loss 1.609173
# iteration 500 / 1000: loss 1.467504
# iteration 600 / 1000: loss 1.499271
# iteration 700 / 1000: loss 1.347472
# iteration 800 / 1000: loss 1.270819
# iteration 900 / 1000: loss 1.305368
# Training Accuracy 0.5633265306122449, Validation Accuracy 0.532
# Training Accuracy 0.5633265306122449, Validation Accuracy 0.532
# h=350,b=350, lr=0.01, reg =0.0002
# iteration 0 / 1000: loss 2.302894
# iteration 100 / 1000: loss 2.089253
# iteration 200 / 1000: loss 1.785910
# iteration 300 / 1000: loss 1.656695
# iteration 400 / 1000: loss 1.517536
# iteration 500 / 1000: loss 1.534111
# iteration 600 / 1000: loss 1.495353
# iteration 700 / 1000: loss 1.427470
# iteration 800 / 1000: loss 1.349853
# iteration 900 / 1000: loss 1.399531
# Training Accuracy 0.5494489795918367, Validation Accuracy 0.507
# Training Accuracy 0.5494489795918367, Validation Accuracy 0.507
# h=350,b=400, lr=0.01, reg =0.0002
# iteration 0 / 1000: loss 2.302838
# iteration 100 / 1000: loss 2.067887
# iteration 200 / 1000: loss 1.847314
# iteration 300 / 1000: loss 1.713298
# iteration 400 / 1000: loss 1.595785
# iteration 500 / 1000: loss 1.527084
# iteration 600 / 1000: loss 1.498440
# iteration 700 / 1000: loss 1.404055
# iteration 800 / 1000: loss 1.345133
# iteration 900 / 1000: loss 1.420226
# Training Accuracy 0.5481224489795918, Validation Accuracy 0.5
# Training Accuracy 0.5481224489795918, Validation Accuracy 0.5
# h=400,b=350, lr=0.01, reg =0.0002
# iteration 0 / 1000: loss 2.302872
# iteration 100 / 1000: loss 2.104305
# iteration 200 / 1000: loss 1.868385
# iteration 300 / 1000: loss 1.720737
# iteration 400 / 1000: loss 1.685382
# iteration 500 / 1000: loss 1.493432
# iteration 600 / 1000: loss 1.467842
# iteration 700 / 1000: loss 1.428393
# iteration 800 / 1000: loss 1.518440
# iteration 900 / 1000: loss 1.381725
# Training Accuracy 0.5285510204081633, Validation Accuracy 0.502
# Training Accuracy 0.5285510204081633, Validation Accuracy 0.502
# h=400,b=400, lr=0.01, reg =0.0002
# iteration 0 / 1000: loss 2.302895
# iteration 100 / 1000: loss 2.073611
# iteration 200 / 1000: loss 1.695867
# iteration 300 / 1000: loss 1.662146
# iteration 400 / 1000: loss 1.624940
# iteration 500 / 1000: loss 1.497951
# iteration 600 / 1000: loss 1.394533
# iteration 700 / 1000: loss 1.414947
# iteration 800 / 1000: loss 1.431321
# iteration 900 / 1000: loss 1.252605
# Training Accuracy 0.5610408163265306, Validation Accuracy 0.529
# Training Accuracy 0.5610408163265306, Validation Accuracy 0.529
# h=350,b=350, lr=0.01, reg =0.001
# iteration 0 / 1000: loss 2.303801
# iteration 100 / 1000: loss 2.037680
# iteration 200 / 1000: loss 1.786594
# iteration 300 / 1000: loss 1.670747
# iteration 400 / 1000: loss 1.680630
# iteration 500 / 1000: loss 1.576407
# iteration 600 / 1000: loss 1.494592
# iteration 700 / 1000: loss 1.470513
# iteration 800 / 1000: loss 1.397603
# iteration 900 / 1000: loss 1.336383
# Training Accuracy 0.5491836734693878, Validation Accuracy 0.499
# Training Accuracy 0.5491836734693878, Validation Accuracy 0.499
# h=350,b=400, lr=0.01, reg =0.001
# iteration 0 / 1000: loss 2.303807
# iteration 100 / 1000: loss 2.023469
# iteration 200 / 1000: loss 1.800704
# iteration 300 / 1000: loss 1.659850
# iteration 400 / 1000: loss 1.606470
# iteration 500 / 1000: loss 1.510485
# iteration 600 / 1000: loss 1.422979
# iteration 700 / 1000: loss 1.370143
# iteration 800 / 1000: loss 1.359209
# iteration 900 / 1000: loss 1.282378
# Training Accuracy 0.5566530612244898, Validation Accuracy 0.509
# Training Accuracy 0.5566530612244898, Validation Accuracy 0.509
# h=400,b=350, lr=0.01, reg =0.001
# iteration 0 / 1000: loss 2.303985
# iteration 100 / 1000: loss 2.068219
# iteration 200 / 1000: loss 1.801730
# iteration 300 / 1000: loss 1.753882
# iteration 400 / 1000: loss 1.788491
# iteration 500 / 1000: loss 1.519656
# iteration 600 / 1000: loss 1.465320
# iteration 700 / 1000: loss 1.430830
# iteration 800 / 1000: loss 1.378400
# iteration 900 / 1000: loss 1.367414
# Training Accuracy 0.5276734693877551, Validation Accuracy 0.519
# Training Accuracy 0.5276734693877551, Validation Accuracy 0.519
# h=400,b=400, lr=0.01, reg =0.001
# iteration 0 / 1000: loss 2.304048
# iteration 100 / 1000: loss 2.053611
# iteration 200 / 1000: loss 1.831392
# iteration 300 / 1000: loss 1.661638
# iteration 400 / 1000: loss 1.536177
# iteration 500 / 1000: loss 1.661114
# iteration 600 / 1000: loss 1.409349
# iteration 700 / 1000: loss 1.374241
# iteration 800 / 1000: loss 1.397993
# iteration 900 / 1000: loss 1.375730
# Training Accuracy 0.5545918367346939, Validation Accuracy 0.503
# Training Accuracy 0.5545918367346939, Validation Accuracy 0.503
# h=350,b=350, lr=0.015, reg =0.0001
# iteration 0 / 1000: loss 2.302662
# iteration 100 / 1000: loss 1.926038
# iteration 200 / 1000: loss 1.661203
# iteration 300 / 1000: loss 1.587798
# iteration 400 / 1000: loss 1.574342
# iteration 500 / 1000: loss 1.400900
# iteration 600 / 1000: loss 1.394388
# iteration 700 / 1000: loss 1.373256
# iteration 800 / 1000: loss 1.347007
# iteration 900 / 1000: loss 1.190330
# Training Accuracy 0.5751428571428572, Validation Accuracy 0.536
# Training Accuracy 0.5751428571428572, Validation Accuracy 0.536
# h=350,b=400, lr=0.015, reg =0.0001
# iteration 0 / 1000: loss 2.302678
# iteration 100 / 1000: loss 1.949797
# iteration 200 / 1000: loss 1.730552
# iteration 300 / 1000: loss 1.497839
# iteration 400 / 1000: loss 1.483580
# iteration 500 / 1000: loss 1.440213
# iteration 600 / 1000: loss 1.370947
# iteration 700 / 1000: loss 1.457747
# iteration 800 / 1000: loss 1.253524
# iteration 900 / 1000: loss 1.267060
# Training Accuracy 0.5722244897959183, Validation Accuracy 0.506
# Training Accuracy 0.5722244897959183, Validation Accuracy 0.506
# h=400,b=350, lr=0.015, reg =0.0001
# iteration 0 / 1000: loss 2.302804
# iteration 100 / 1000: loss 1.919853
# iteration 200 / 1000: loss 1.715697
# iteration 300 / 1000: loss 1.561501
# iteration 400 / 1000: loss 1.533488
# iteration 500 / 1000: loss 1.419013
# iteration 600 / 1000: loss 1.375197
# iteration 700 / 1000: loss 1.464205
# iteration 800 / 1000: loss 1.222166
# iteration 900 / 1000: loss 1.271687
# Training Accuracy 0.5731428571428572, Validation Accuracy 0.529
# Training Accuracy 0.5731428571428572, Validation Accuracy 0.529
# h=400,b=400, lr=0.015, reg =0.0001
# iteration 0 / 1000: loss 2.302692
# iteration 100 / 1000: loss 1.932017
# iteration 200 / 1000: loss 1.624217
# iteration 300 / 1000: loss 1.622596
# iteration 400 / 1000: loss 1.614807
# iteration 500 / 1000: loss 1.379140
# iteration 600 / 1000: loss 1.470302
# iteration 700 / 1000: loss 1.215386
# iteration 800 / 1000: loss 1.398471
# iteration 900 / 1000: loss 1.217283
# Training Accuracy 0.557, Validation Accuracy 0.506
# Training Accuracy 0.557, Validation Accuracy 0.506
# h=350,b=350, lr=0.015, reg =0.0002
# iteration 0 / 1000: loss 2.302868
# iteration 100 / 1000: loss 1.923768
# iteration 200 / 1000: loss 1.752232
# iteration 300 / 1000: loss 1.564005
# iteration 400 / 1000: loss 1.603057
# iteration 500 / 1000: loss 1.398194
# iteration 600 / 1000: loss 1.342508
# iteration 700 / 1000: loss 1.405753
# iteration 800 / 1000: loss 1.260049
# iteration 900 / 1000: loss 1.330516
# Training Accuracy 0.5587755102040817, Validation Accuracy 0.508
# Training Accuracy 0.5587755102040817, Validation Accuracy 0.508
# h=350,b=400, lr=0.015, reg =0.0002
# iteration 0 / 1000: loss 2.302801
# iteration 100 / 1000: loss 1.930417
# iteration 200 / 1000: loss 1.714506
# iteration 300 / 1000: loss 1.590192
# iteration 400 / 1000: loss 1.519185
# iteration 500 / 1000: loss 1.375188
# iteration 600 / 1000: loss 1.282748
# iteration 700 / 1000: loss 1.301475
# iteration 800 / 1000: loss 1.308671
# iteration 900 / 1000: loss 1.314359
# Training Accuracy 0.5478571428571428, Validation Accuracy 0.516
# Training Accuracy 0.5478571428571428, Validation Accuracy 0.516
# h=400,b=350, lr=0.015, reg =0.0002
# iteration 0 / 1000: loss 2.302853
# iteration 100 / 1000: loss 1.866059
# iteration 200 / 1000: loss 1.745364
# iteration 300 / 1000: loss 1.688460
# iteration 400 / 1000: loss 1.586630
# iteration 500 / 1000: loss 1.483860
# iteration 600 / 1000: loss 1.406991
# iteration 700 / 1000: loss 1.295646
# iteration 800 / 1000: loss 1.350996
# iteration 900 / 1000: loss 1.235684
# Training Accuracy 0.5679591836734694, Validation Accuracy 0.512
# Training Accuracy 0.5679591836734694, Validation Accuracy 0.512
# h=400,b=400, lr=0.015, reg =0.0002
# iteration 0 / 1000: loss 2.302919
# iteration 100 / 1000: loss 1.923508
# iteration 200 / 1000: loss 1.757989
# iteration 300 / 1000: loss 1.557633
# iteration 400 / 1000: loss 1.534074
# iteration 500 / 1000: loss 1.423508
# iteration 600 / 1000: loss 1.438041
# iteration 700 / 1000: loss 1.280492
# iteration 800 / 1000: loss 1.254299
# iteration 900 / 1000: loss 1.204200
# Training Accuracy 0.5819183673469388, Validation Accuracy 0.526
# Training Accuracy 0.5819183673469388, Validation Accuracy 0.526
# h=350,b=350, lr=0.015, reg =0.001
# iteration 0 / 1000: loss 2.303736
# iteration 100 / 1000: loss 1.917033
# iteration 200 / 1000: loss 1.706157
# iteration 300 / 1000: loss 1.581461
# iteration 400 / 1000: loss 1.560770
# iteration 500 / 1000: loss 1.399945
# iteration 600 / 1000: loss 1.381536
# iteration 700 / 1000: loss 1.421092
# iteration 800 / 1000: loss 1.320960
# iteration 900 / 1000: loss 1.390555
# Training Accuracy 0.5598775510204081, Validation Accuracy 0.514
# Training Accuracy 0.5598775510204081, Validation Accuracy 0.514
# h=350,b=400, lr=0.015, reg =0.001
# iteration 0 / 1000: loss 2.303811
# iteration 100 / 1000: loss 1.905104
# iteration 200 / 1000: loss 1.638827
# iteration 300 / 1000: loss 1.617391
# iteration 400 / 1000: loss 1.535436
# iteration 500 / 1000: loss 1.425202
# iteration 600 / 1000: loss 1.314909
# iteration 700 / 1000: loss 1.359953
# iteration 800 / 1000: loss 1.364389
# iteration 900 / 1000: loss 1.360460
# Training Accuracy 0.5469183673469388, Validation Accuracy 0.487
# Training Accuracy 0.5469183673469388, Validation Accuracy 0.487
# h=400,b=350, lr=0.015, reg =0.001
# iteration 0 / 1000: loss 2.303961
# iteration 100 / 1000: loss 1.946896
# iteration 200 / 1000: loss 1.693246
# iteration 300 / 1000: loss 1.689256
# iteration 400 / 1000: loss 1.600289
# iteration 500 / 1000: loss 1.496745
# iteration 600 / 1000: loss 1.337643
# iteration 700 / 1000: loss 1.389842
# iteration 800 / 1000: loss 1.408934
# iteration 900 / 1000: loss 1.274012
# Training Accuracy 0.5673877551020409, Validation Accuracy 0.53
# Training Accuracy 0.5673877551020409, Validation Accuracy 0.53
# h=400,b=400, lr=0.015, reg =0.001
# iteration 0 / 1000: loss 2.303980
# iteration 100 / 1000: loss 1.965857
# iteration 200 / 1000: loss 1.574517
# iteration 300 / 1000: loss 1.526380
# iteration 400 / 1000: loss 1.522058
# iteration 500 / 1000: loss 1.411105
# iteration 600 / 1000: loss 1.254027
# iteration 700 / 1000: loss 1.325606
# iteration 800 / 1000: loss 1.325487
# iteration 900 / 1000: loss 1.123375
# Training Accuracy 0.5857346938775511, Validation Accuracy 0.528
# Training Accuracy 0.5857346938775511, Validation Accuracy 0.528
# h=350,b=350, lr=0.018, reg =0.0001
# iteration 0 / 1000: loss 2.302761
# iteration 100 / 1000: loss 1.916860
# iteration 200 / 1000: loss 1.798759
# iteration 300 / 1000: loss 1.545339
# iteration 400 / 1000: loss 1.470779
# iteration 500 / 1000: loss 1.447154
# iteration 600 / 1000: loss 1.549458
# iteration 700 / 1000: loss 1.248819
# iteration 800 / 1000: loss 1.252313
# iteration 900 / 1000: loss 1.284567
# Training Accuracy 0.5683469387755102, Validation Accuracy 0.515
# Training Accuracy 0.5683469387755102, Validation Accuracy 0.515
# h=350,b=400, lr=0.018, reg =0.0001
# iteration 0 / 1000: loss 2.302710
# iteration 100 / 1000: loss 1.890021
# iteration 200 / 1000: loss 1.708499
# iteration 300 / 1000: loss 1.656023
# iteration 400 / 1000: loss 1.336854
# iteration 500 / 1000: loss 1.505724
# iteration 600 / 1000: loss 1.437735
# iteration 700 / 1000: loss 1.372673
# iteration 800 / 1000: loss 1.416332
# iteration 900 / 1000: loss 1.349143
# Training Accuracy 0.5753265306122449, Validation Accuracy 0.504
# Training Accuracy 0.5753265306122449, Validation Accuracy 0.504
# h=400,b=350, lr=0.018, reg =0.0001
# iteration 0 / 1000: loss 2.302734
# iteration 100 / 1000: loss 1.855521
# iteration 200 / 1000: loss 1.576281
# iteration 300 / 1000: loss 1.654923
# iteration 400 / 1000: loss 1.552369
# iteration 500 / 1000: loss 1.418290
# iteration 600 / 1000: loss 1.511871
# iteration 700 / 1000: loss 1.288966
# iteration 800 / 1000: loss 1.215066
# iteration 900 / 1000: loss 1.490010
# Training Accuracy 0.5920408163265306, Validation Accuracy 0.524
# Training Accuracy 0.5920408163265306, Validation Accuracy 0.524
# h=400,b=400, lr=0.018, reg =0.0001
# iteration 0 / 1000: loss 2.302716
# iteration 100 / 1000: loss 1.889284
# iteration 200 / 1000: loss 1.624718
# iteration 300 / 1000: loss 1.548691
# iteration 400 / 1000: loss 1.717940
# iteration 500 / 1000: loss 1.405722
# iteration 600 / 1000: loss 1.434710
# iteration 700 / 1000: loss 1.350497
# iteration 800 / 1000: loss 1.374010
# iteration 900 / 1000: loss 1.159921
# Training Accuracy 0.5676734693877551, Validation Accuracy 0.521
# Training Accuracy 0.5676734693877551, Validation Accuracy 0.521
# h=350,b=350, lr=0.018, reg =0.0002
# iteration 0 / 1000: loss 2.302861
# iteration 100 / 1000: loss 1.859282
# iteration 200 / 1000: loss 1.705323
# iteration 300 / 1000: loss 1.661718
# iteration 400 / 1000: loss 1.685779
# iteration 500 / 1000: loss 1.408431
# iteration 600 / 1000: loss 1.369009
# iteration 700 / 1000: loss 1.426757
# iteration 800 / 1000: loss 1.350269
# iteration 900 / 1000: loss 1.266905
# Training Accuracy 0.5711632653061225, Validation Accuracy 0.524
# Training Accuracy 0.5711632653061225, Validation Accuracy 0.524
# h=350,b=400, lr=0.018, reg =0.0002
# iteration 0 / 1000: loss 2.302846
# iteration 100 / 1000: loss 1.924764
# iteration 200 / 1000: loss 1.766510
# iteration 300 / 1000: loss 1.566403
# iteration 400 / 1000: loss 1.439690
# iteration 500 / 1000: loss 1.385109
# iteration 600 / 1000: loss 1.466814
# iteration 700 / 1000: loss 1.454079
# iteration 800 / 1000: loss 1.356818
# iteration 900 / 1000: loss 1.310906
# Training Accuracy 0.5837346938775511, Validation Accuracy 0.524
# Training Accuracy 0.5837346938775511, Validation Accuracy 0.524
# h=400,b=350, lr=0.018, reg =0.0002
# iteration 0 / 1000: loss 2.302994
# iteration 100 / 1000: loss 1.893553
# iteration 200 / 1000: loss 1.622810
# iteration 300 / 1000: loss 1.508571
# iteration 400 / 1000: loss 1.497586
# iteration 500 / 1000: loss 1.414158
# iteration 600 / 1000: loss 1.434874
# iteration 700 / 1000: loss 1.308699
# iteration 800 / 1000: loss 1.342713
# iteration 900 / 1000: loss 1.268035
# Training Accuracy 0.5749387755102041, Validation Accuracy 0.535
# Training Accuracy 0.5749387755102041, Validation Accuracy 0.535
# h=400,b=400, lr=0.018, reg =0.0002
# iteration 0 / 1000: loss 2.302792
# iteration 100 / 1000: loss 1.888897
# iteration 200 / 1000: loss 1.712912
# iteration 300 / 1000: loss 1.598163
# iteration 400 / 1000: loss 1.452997
# iteration 500 / 1000: loss 1.466487
# iteration 600 / 1000: loss 1.490740
# iteration 700 / 1000: loss 1.321569
# iteration 800 / 1000: loss 1.297477
# iteration 900 / 1000: loss 1.242776
# Training Accuracy 0.5742857142857143, Validation Accuracy 0.519
# Training Accuracy 0.5742857142857143, Validation Accuracy 0.519
# h=350,b=350, lr=0.018, reg =0.001
# iteration 0 / 1000: loss 2.303795
# iteration 100 / 1000: loss 1.826156
# iteration 200 / 1000: loss 1.755480
# iteration 300 / 1000: loss 1.619086
# iteration 400 / 1000: loss 1.709969
# iteration 500 / 1000: loss 1.639972
# iteration 600 / 1000: loss 1.352200
# iteration 700 / 1000: loss 1.452756
# iteration 800 / 1000: loss 1.238519
# iteration 900 / 1000: loss 1.333904
# Training Accuracy 0.5584285714285714, Validation Accuracy 0.501
# Training Accuracy 0.5584285714285714, Validation Accuracy 0.501
# h=350,b=400, lr=0.018, reg =0.001
# iteration 0 / 1000: loss 2.303890
# iteration 100 / 1000: loss 1.909450
# iteration 200 / 1000: loss 1.684728
# iteration 300 / 1000: loss 1.525494
# iteration 400 / 1000: loss 1.437740
# iteration 500 / 1000: loss 1.440445
# iteration 600 / 1000: loss 1.349557
# iteration 700 / 1000: loss 1.240585
# iteration 800 / 1000: loss 1.208025
# iteration 900 / 1000: loss 1.402933
# Training Accuracy 0.5876122448979592, Validation Accuracy 0.519
# Training Accuracy 0.5876122448979592, Validation Accuracy 0.519
# h=400,b=350, lr=0.018, reg =0.001
# iteration 0 / 1000: loss 2.304000
# iteration 100 / 1000: loss 1.793828
# iteration 200 / 1000: loss 1.821374
# iteration 300 / 1000: loss 1.637294
# iteration 400 / 1000: loss 1.707583
# iteration 500 / 1000: loss 1.418380
# iteration 600 / 1000: loss 1.320796
# iteration 700 / 1000: loss 1.446332
# iteration 800 / 1000: loss 1.303196
# iteration 900 / 1000: loss 1.192313
# Training Accuracy 0.5848979591836735, Validation Accuracy 0.536
# Training Accuracy 0.5848979591836735, Validation Accuracy 0.536
# h=400,b=400, lr=0.018, reg =0.001
# iteration 0 / 1000: loss 2.303955
# iteration 100 / 1000: loss 1.893239
# iteration 200 / 1000: loss 1.673676
# iteration 300 / 1000: loss 1.536957
# iteration 400 / 1000: loss 1.441056
# iteration 500 / 1000: loss 1.290581
# iteration 600 / 1000: loss 1.447987
# iteration 700 / 1000: loss 1.302914
# iteration 800 / 1000: loss 1.291711
# iteration 900 / 1000: loss 1.215484
# Training Accuracy 0.5758775510204082, Validation Accuracy 0.527
# Training Accuracy 0.5758775510204082, Validation Accuracy 0.527

# %%
# Print out results.
for lr, reg, h, b  in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg, h, b)]
    print("lr = {}, reg = {}, h={}, b = {}, train = {}, valid = {}".format(lr, reg, h, b, train_accuracy, val_accuracy))
     
print('best validation accuracy achieved during cross-validation: %f' % best_val)
print("Best: lr = {}, reg = {}, hidden_size = {}, batch = {}, (train, valid) = {}".format(best_lr, best_reg, best_hidden, best_batch ,results[(best_lr, best_reg, best_hidden, best_batch)] ))
# print(results)
# Out:
# lr = 0.01, reg = 0.0001, h=350, b = 350, train = 0.523469387755102, valid = 0.506
# lr = 0.01, reg = 0.0001, h=350, b = 400, train = 0.5320204081632653, valid = 0.478
# lr = 0.01, reg = 0.0001, h=400, b = 350, train = 0.5467142857142857, valid = 0.495
# lr = 0.01, reg = 0.0001, h=400, b = 400, train = 0.5633265306122449, valid = 0.532
# lr = 0.01, reg = 0.0002, h=350, b = 350, train = 0.5494489795918367, valid = 0.507
# lr = 0.01, reg = 0.0002, h=350, b = 400, train = 0.5481224489795918, valid = 0.5
# lr = 0.01, reg = 0.0002, h=400, b = 350, train = 0.5285510204081633, valid = 0.502
# lr = 0.01, reg = 0.0002, h=400, b = 400, train = 0.5610408163265306, valid = 0.529
# lr = 0.01, reg = 0.001, h=350, b = 350, train = 0.5491836734693878, valid = 0.499
# lr = 0.01, reg = 0.001, h=350, b = 400, train = 0.5566530612244898, valid = 0.509
# lr = 0.01, reg = 0.001, h=400, b = 350, train = 0.5276734693877551, valid = 0.519
# lr = 0.01, reg = 0.001, h=400, b = 400, train = 0.5545918367346939, valid = 0.503
# lr = 0.015, reg = 0.0001, h=350, b = 350, train = 0.5751428571428572, valid = 0.536
# lr = 0.015, reg = 0.0001, h=350, b = 400, train = 0.5722244897959183, valid = 0.506
# lr = 0.015, reg = 0.0001, h=400, b = 350, train = 0.5731428571428572, valid = 0.529
# lr = 0.015, reg = 0.0001, h=400, b = 400, train = 0.557, valid = 0.506
# lr = 0.015, reg = 0.0002, h=350, b = 350, train = 0.5587755102040817, valid = 0.508
# lr = 0.015, reg = 0.0002, h=350, b = 400, train = 0.5478571428571428, valid = 0.516
# lr = 0.015, reg = 0.0002, h=400, b = 350, train = 0.5679591836734694, valid = 0.512
# lr = 0.015, reg = 0.0002, h=400, b = 400, train = 0.5819183673469388, valid = 0.526
# lr = 0.015, reg = 0.001, h=350, b = 350, train = 0.5598775510204081, valid = 0.514
# lr = 0.015, reg = 0.001, h=350, b = 400, train = 0.5469183673469388, valid = 0.487
# lr = 0.015, reg = 0.001, h=400, b = 350, train = 0.5673877551020409, valid = 0.53
# lr = 0.015, reg = 0.001, h=400, b = 400, train = 0.5857346938775511, valid = 0.528
# lr = 0.018, reg = 0.0001, h=350, b = 350, train = 0.5683469387755102, valid = 0.515
# lr = 0.018, reg = 0.0001, h=350, b = 400, train = 0.5753265306122449, valid = 0.504
# lr = 0.018, reg = 0.0001, h=400, b = 350, train = 0.5920408163265306, valid = 0.524
# lr = 0.018, reg = 0.0001, h=400, b = 400, train = 0.5676734693877551, valid = 0.521
# lr = 0.018, reg = 0.0002, h=350, b = 350, train = 0.5711632653061225, valid = 0.524
# lr = 0.018, reg = 0.0002, h=350, b = 400, train = 0.5837346938775511, valid = 0.524
# lr = 0.018, reg = 0.0002, h=400, b = 350, train = 0.5749387755102041, valid = 0.535
# lr = 0.018, reg = 0.0002, h=400, b = 400, train = 0.5742857142857143, valid = 0.519
# lr = 0.018, reg = 0.001, h=350, b = 350, train = 0.5584285714285714, valid = 0.501
# lr = 0.018, reg = 0.001, h=350, b = 400, train = 0.5876122448979592, valid = 0.519
# lr = 0.018, reg = 0.001, h=400, b = 350, train = 0.5848979591836735, valid = 0.536
# lr = 0.018, reg = 0.001, h=400, b = 400, train = 0.5758775510204082, valid = 0.527
# best validation accuracy achieved during cross-validation: 0.536000
# Best: lr = 0.018, reg = 0.001, hidden_size = 400, batch = 350, (train, valid) = (0.5848979591836735, 0.536)

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.532

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$ 1 and 3.
#
# $\color{blue}{\textit Your Explanation:}$
# Adding more data will generlaize the model and even data augmentation will do the trick. The increase regularization strength will help to generlaize the model better by penalizing the weights.
#
# Note:
# In the context of this assignment,  as you can see from the training and validation loss, adding more hidden units is increasing the accuracy. It is because of the fact that adding more hidden units will increase the model complexity and it helps the model to caputre the complexity of the data (i.e., enable the model to caputre the complex features).
